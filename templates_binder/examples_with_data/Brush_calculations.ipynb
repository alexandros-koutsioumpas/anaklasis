# %% [markdown]
# ## Multiple Neutron Reflectivity calculations for polymer Brushes
#
# Suppose that we want to compare the theoretical reflectivity of polymer brushes at the Quartz/d-toluene interface for different values of their thickness and grafting density. Polymer brushes have parabolic volume fraction profiles of the form: $\phi(z) = \phi(0) \left[ 1 - (\frac{z}{L})^2\right]$ where $\phi$ is the polymer volume fraction, $L$ is the brush extension and $z$ the distance from the substrate.

# %% [markdown]
# First let's import anaklasis and matplotlib that we will use later for plotting stuff.

# %%
from anaklasis import anaklasis
import matplotlib.pyplot as plt

# %% [markdown]
# We name the project as 'none' which results in no pdf plots or ASCII file output beeing generated by _anaklasis_

# %%
project='none'

# %% [markdown]
# We then define that we will use a single patch and also add the instrumental parameters.

# %%
patches=[1.0]

# %%
resolution=[0.06] # dQ/Q=6%
background = [0.0] #no background
scale = [1.0]
qmax = [0.1]

# %% [markdown]
# Let's start building the model. First we create the Quartz/d-toluene semi-infinite layers.

# %%
system=[]
system.append([
	# rho irho depth sigma solv name
	[  4.32e-6, 0.0, 0, 5, 0.0, 'Quartz'],
	[  5.86e-6, 0.0,  0, 0, 1.0, 'd-toluene'],
	])

# %% [markdown]
# We will now insert between these two defined layers, 50 slices representing the polymer brush. These layers will all have the same polymer sld and a varying solvent volume fraction ($1-\phi(z)$). For this reason we first define a symbolic expression for the solvent volume fraction.

# %%
expr='1-p0+(p0/(p1**2))*((p1/50)*(n-0.5))**2'

# %% [markdown]
# where p0 and p1 are global parameters (we will define them later) representing $\phi(0)$ and $L$. $n$ is the layer number that for our brush layer runs from 1 to 50. So the expression $(p1/50)*(n-0.5)$ gives the $z$ distance of each slice from the substrate. So now we insert the slices of the brush in the model _list_ using a _for loop_.

# %%
for i in range(50): 
	system[0].insert(1,[ 1.41e-6, 0.0, 'p1/50', 'p1/100', expr, 'layer'])

# %% [markdown]
# Note that we insert in system[0] since counting in python starts from zero. We start insering in position one since in position 0 we have the already defined semi-infinite fronting. All slices have the same sld, same thickness and we also apply a roughness (half slice thickness) to smooth the profile. The volume fraction profile is set according to the above defined symbolic expression.

# %% [markdown]
# Now we may define sets of global parameters

# %%
global_param_A = [
    # param value  description
	['p0', 0.20, 'phi0'],
	['p1', 700, 'brush_length'],
	]

global_param_B = [
    # param value  description
	['p0', 0.40, 'phi0'],
	['p1', 300, 'brush_length'],
	]

global_param_C = [
    # param value  description
	['p0', 0.10, 'phi0'],
	['p1', 1200, 'brush_length'],
	]

# %% [markdown]
# For each set of parameters we may call the _anaklasis.calculate_ function and store the results in _tuples_. Note that we set _plot=False_ since we do not need a summary plot to be exported.

# %%
results_A = anaklasis.calculate(project, resolution, 
	patches, system, global_param_A, 
	background, scale, qmax, plot=False)

results_B = anaklasis.calculate(project, resolution, 
	patches, system, global_param_B, 
	background, scale, qmax, plot=False)

results_C = anaklasis.calculate(project, resolution, 
	patches, system, global_param_C, 
	background, scale, qmax, plot=False)
# Out:
# --------------------------------------------------------------------
# Program ANAKLASIS - Calculation Module for X-ray/Neutron reflection
# version 1.2, February 2021
# developed by Dr. Alexandros Koutsioumpas. JCNS @ MLZ
# for bugs and requests contact: a.koutsioumpas[at]fz-juelich.de
# --------------------------------------------------------------------
#
#
# Instrumental Resolution, dQ/Q: 0.06
# --------------------------------------------------------------------
# Quartz real sld (10^-6 A^-2)      = 4.32
# Quartz imaginary sld (10^-6 A^-2) = 0.00
# Quartz thickness (A)              = 0.00
# Quartz/layer roughness (A) = 5.00
# Quartz solvent volume fraction    = 0.00
# --------------------------------------------------------------------
# layer real sld (10^-6 A^-2)      = 1.41
# layer imaginary sld (10^-6 A^-2) = 0.00
# layer thickness (A)              = 14.00 (parametric), -> p1/50
# layer/layer roughness (A) = 7.00 (parametric), -> p1/100
# ...

# %% [markdown]
# the three tuples contain three lists corresponding to calculated reflectivity, sld and solvent profile. We may use them to produce a plot for the reflectivity of the three systems.

# %%
plt.figure()
plt.plot(results_A[0][:,0],results_A[0][:,1],color='red')
plt.plot(results_B[0][:,0],results_B[0][:,1],color='blue')
plt.plot(results_C[0][:,0],results_C[0][:,1],color='green')
plt.yscale('log')
plt.xlabel(r'$Q(\AA^{-1})$')
plt.ylabel(r'$R(Q)$')
plt.grid(True)
plt.draw()

# %% [markdown]
# we may do the same for the sld profiles that are stored in the second _list_ of the _tuple_ (so [1] in _python_). Also since we have a single patch, our 2-column (z,sld) data are located in results results_A[1][0], results_B[1][0] and results_C[1][0]

# %%
plt.figure()
plt.plot(results_A[1][0][:,0],results_A[1][0][:,1],color='red')
plt.plot(results_B[1][0][:,0],results_B[1][0][:,1],color='blue')
plt.plot(results_C[1][0][:,0],results_C[1][0][:,1],color='green')
plt.xlabel(r'$z(\AA)$')
plt.ylabel(r'$sld(10^{-6}\AA^{-2})$')
plt.draw()

# %% [markdown]
# Do the same for the solvent volume fraction profile of the 3 brushes that is contained in the third _list_ of the _tuple_.

# %%
plt.figure()
plt.plot(results_A[2][0][:,0],results_A[2][0][:,1],color='red')
plt.plot(results_B[2][0][:,0],results_B[2][0][:,1],color='blue')
plt.plot(results_C[2][0][:,0],results_C[2][0][:,1],color='green')
plt.xlabel(r'$z(\AA)$')
plt.ylabel(r'$solvent volume fraction$')
plt.draw()
